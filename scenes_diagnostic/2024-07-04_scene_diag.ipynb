# %% [markdown]
# # Scenes diagnostic
# - identity some patterns in the trajectories

# %% [markdown]
# #### Imports

# %%
import sys
import os
from glob import glob

import cartopy.geodesic as geod
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.geodesic import Geodesic

import scipy
import scipy.signal

import numpy as np
import xarray as xr
import vaex
import pandas as pd

import jax
import jax.numpy as jnp
import jaxparrow as jpw

import clouddrift as cd

sys.path.append(os.path.abspath(os.path.join('..', 'common_utils')))
from utils import *
from utils_plots import plot_scene

# %matplotlib inline
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['figure.dpi'] = 300


drifters_directory = '/home/bouxdecl/Documents/data/DRIFTERS'
path_fields = '/home/bouxdecl/Documents/MEOM_internship_2024/save_data/fields_data'

path_save_data = '/home/bouxdecl/Documents/MEOM_internship_2024/save_data/drifters_scenes'

# %% [markdown]
# ## Data and utils

# %% [markdown]
# #### field data

# %%
# L3 field data
ds_swot = xr.open_dataset(os.path.join(path_fields, 'field_L3SWOT.nc'))

# %%
scenes_filtered = xr.open_dataset('/home/bouxdecl/Documents/MEOM_internship_2024/save_data/drifters_scenes/scenes_one_traj_filtrage_classique.nc')
scenes_new      = xr.open_dataset('/home/bouxdecl/Documents/MEOM_internship_2024/save_data/drifters_scenes/scenes_one_traj_lwpass36h_g10h.nc')
scenes_raw      = xr.open_dataset('/home/bouxdecl/Documents/MEOM_internship_2024/save_data/drifters_scenes/scenes_one_traj_NOfiltrage.nc')

scenes_7h       = xr.open_dataset('/home/bouxdecl/Documents/MEOM_internship_2024/save_data/drifters_scenes/scenes_one_traj_svp30min_3_id_5_7hgaussienne')

# %% [markdown]
# ### one scene

# %%
plot_scene(scenes_7h.isel(scene=1), ds_swot, field_vec='geo', time_point=11, points_hours=6)
# Out:
# /home/bouxdecl/miniconda3/envs/gdp6h_duacs_jaxparrow/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1642: UserWarning: The following kwargs were not used by contour: 'label'
#   result = super().contourf(*args, **kwargs)

# %% [markdown]
# ### save all scenes

# %%
for idx in range(scenes_7h.sizes['scene']):
    plot_scene(scenes_7h.isel(scene=idx), ds_swot, field_vec='geo', time_point=4, points_hours=6, 
               
               plot=False, 
               save_name='scenes_one_traj_svp30min_3_id_5_7hgaussienne_scene_{}'.format(idx),
               save_dir= '/home/bouxdecl/Documents/MEOM_internship_2024/save_plots/save_plots_2024_07_05_scene_filtering/scenes_one_traj_svp30min_3_id_5_7hgaussienne_scenes'
               )
# Out:
# /home/bouxdecl/miniconda3/envs/gdp6h_duacs_jaxparrow/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1642: UserWarning: The following kwargs were not used by contour: 'label'
#   result = super().contourf(*args, **kwargs)
# /home/bouxdecl/miniconda3/envs/gdp6h_duacs_jaxparrow/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1642: UserWarning: The following kwargs were not used by contour: 'label'
#   result = super().contourf(*args, **kwargs)
# /home/bouxdecl/miniconda3/envs/gdp6h_duacs_jaxparrow/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1642: UserWarning: The following kwargs were not used by contour: 'label'
#   result = super().contourf(*args, **kwargs)
# /home/bouxdecl/miniconda3/envs/gdp6h_duacs_jaxparrow/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1642: UserWarning: The following kwargs were not used by contour: 'label'
#   result = super().contourf(*args, **kwargs)
# ...
